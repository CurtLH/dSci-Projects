# %%
library(corrplot)

# %%
# read CSV file into a dataframe
full_ads <- read.csv("AdWords_Clean.csv")
ads <- full_ads

# %%
# drop non-relevant columns
ads$Full_description <- NULL
ads$Description <- NULL
ads$Ad_group <- NULL
ads$Description_line_2 <- NULL
ads$Description_line_1 <- NULL
ads$Ad_ID <- NULL
ads$Description_words <- NULL
ads$Ad_state <- NULL
ads$Clean_words <- NULL

# %%
# summarize relevant metric data data
lapply(list(ads$Conv_rate, ads$Bounce_rate, ads$CTR, ads$Description_Length), FUN=summary)
# Out:
# [[1]]
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#   0.0000   0.0000   0.0000   0.3912   0.0000 300.0000
#
# [[2]]
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    0.00   11.32    0.00  100.00
#
# [[3]]
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    0.00    2.24    0.00  200.00
#
# [[4]]
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    2.00   66.00   69.00   68.94   71.00   82.00

# %%
# sort the dataframe by conversion rate
ads <- ads[order(-ads$Conv_rate), ]

# %%
# show the first 5 observations
head(ads)
# Out:
#       shop warranty outdoor Conv_rate CTR   grill lynx grilling accessories
# 25866 0    1        0       300        3.03 0     0    0        0
# 28655 0    0        0       300        5.88 0     0    0        0
# 7073  0    0        0       200        4.17 0     0    0        0
# 10387 1    0        0       200       20.00 0     1    0        0
# 17856 0    0        1       200        8.33 0     0    0        0
# 759   1    0        0       100        3.60 0     0    0        0
#       free ⋯ deals Description_Length fast orders reviews kitchens weber videos
# 25866 1    ⋯ 0     80                 1    0      0       0        0     0
# 28655 1    ⋯ 0     68                 0    0      0       0        0     0
# 7073  1    ⋯ 0     64                 1    0      0       0        0     0
# 10387 1    ⋯ 0     67                 0    0      0       0        0     0
# 17856 1    ⋯ 0     66                 1    0      0       0        0     0
# 759   1    ⋯ 0     68                 0    1      0       0        1     0
#       online today
# 25866 0      0
# 28655 0      0
# 7073  0      1
# 10387 1      0
# 17856 0      0
# 759   0      0

# %%
# show the bivariate correlation matrix
m <- cor(ads)
corrplot(m, method="shade", type="upper", diag=FALSE)
# Out:
# Plot with title “”

# %%
# correlate CTR with all other variables
barplot(cor(ads$CTR, as.matrix(ads[sapply(ads, is.numeric)])), las=2, main="Click Through Rate (CTR) Correlations")
# Out:
# Plot with title “Click Through Rate (CTR) Correlations”

# %%
# correlate Bounce Rate with all other variables
barplot(cor(ads$Bounce_rate, as.matrix(ads[sapply(ads, is.numeric)])), las=2, main="Bounce Rate Correlations")
# Out:
# Plot with title “Bounce Rate Correlations”

# %%
# correlate Conversion Rate with all other variables
barplot(cor(ads$Conv_rate, as.matrix(ads[sapply(ads, is.numeric)])), las=2, main="Conversion Rate Correlations")
# Out:
# Plot with title “Conversion Rate Correlations”
